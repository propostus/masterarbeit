# %%
import pandas as pd

# CSV-Datei laden
df = pd.read_csv("../results/features.csv")

# Überblick
df.head()
# Out:
#                        filename  \
# 0  common_voice_de_40390291.mp3
# 1  common_voice_de_40390130.mp3
# 2  common_voice_de_40390293.mp3
# 3  common_voice_de_40390292.mp3
# 4  common_voice_de_40390295.mp3
#
#                                             filepath       rms  log_energy  \
# 0  audio_files/common_voice_test/common_voice_de_...  0.070955    6.342809
# 1  audio_files/common_voice_test/common_voice_de_...  0.073496    5.667660
# 2  audio_files/common_voice_test/common_voice_de_...  0.062628    6.190309
# 3  audio_files/common_voice_test/common_voice_de_...  0.062612    5.932502
# 4  audio_files/common_voice_test/common_voice_de_...  0.077779    5.714256
#
#    clipping_ratio  crest_factor         snr        hnr          f0  \
# 0        0.000044     14.093398  100.000000   9.792714  139.386363
# 1        0.000093     13.606169   26.897568  16.809673  105.632876
# 2        0.000008     15.967231   26.379932  14.788574  103.422174
# 3        0.000010     15.971399   21.816217  11.594567  143.464117
# 4        0.000020     12.856890   31.941154  11.866283    0.000000
#
#    phoneme_entropy  ...  mfcc_stat_86  mfcc_stat_87  mfcc_stat_88  \
# 0              NaN  ...      0.821122      1.759157      1.606404
# 1         6.039585  ...      0.393766      0.703623      0.466994
# 2         6.172955  ...     -0.432237      0.280757     -0.020892
# 3         6.265943  ...      0.771431     -0.632821      0.060018
# 4         6.641595  ...      1.610606     -0.081578     -0.370387
#
#   mfcc_stat_89  mfcc_stat_90  mfcc_stat_91  P808_MOS    SIGMOS    BAKMOS  \
# 0     0.839586      1.892966      0.945537  3.390479  3.294128  3.601042
# 1    -0.473619      0.965986     -0.185467  3.676935  3.435124  4.091464
# 2    -0.009281     -0.081340     -0.624555  3.898925  3.338875  3.692553
# 3     0.163300     -0.083372      0.720079  3.410538  3.407607  2.948222
# 4     0.936560      0.155083      0.768838  3.220871  3.153388  3.524789
#
#      OVRMOS
# 0  2.815048
# 1  3.180969
# 2  2.884356
# 3  2.701955
# 4  2.670215
#
# [5 rows x 133 columns]

# %%
print(f"Anzahl Zeilen: {df.shape[0]}")
print(f"Anzahl Spalten: {df.shape[1]}")
# Out:
# Anzahl Zeilen: 12
# Anzahl Spalten: 133

# %%
df.info()

# Fehlende Werte prüfen
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Columns: 133 entries, filename to OVRMOS
# dtypes: float64(130), object(3)
# memory usage: 12.6+ KB
# filename          0
# filepath          0
# rms               0
# log_energy        0
# clipping_ratio    0
#                  ..
# mfcc_stat_91      0
# P808_MOS          0
# SIGMOS            0
# BAKMOS            0
# OVRMOS            0
# Length: 133, dtype: int64

# %%
df.describe()
# Out:
#              rms  log_energy  clipping_ratio  crest_factor         snr  \
# count  12.000000   12.000000       12.000000     12.000000   12.000000
# mean    0.078451    6.242535        0.000030     13.062751   34.648342
# std     0.013487    0.378771        0.000024      2.041963   21.548569
# min     0.062612    5.667660        0.000008      9.106246   21.816217
# 25%     0.070052    5.974369        0.000013     12.243997   24.726197
# 50%     0.077056    6.236525        0.000019     12.978711   28.231236
# 75%     0.081776    6.496746        0.000043     14.282390   31.793104
# max     0.109815    6.872661        0.000093     15.971399  100.000000
#
#              hnr          f0  phoneme_entropy  rt60_reverberation  \
# count  12.000000   12.000000        11.000000           12.000000
# mean   14.393210  118.442545         6.175030            3.851562
# std     2.816496   63.327645         0.271951            1.956464
# min     9.792714    0.000000         5.712626            1.449750
# 25%    11.825364  101.817366         6.021191            2.540937
# 50%    14.803304  104.754741         6.172955            3.608937
# 75%    16.701571  129.718565         6.251093            4.632750
# max    19.013226  282.571846         6.641595            7.394250
#
#        spectral_bandwidth  ...  mfcc_stat_86  mfcc_stat_87  mfcc_stat_88  \
# count           12.000000  ...     12.000000     12.000000     12.000000
# mean          1870.825909  ...      0.094972      0.173993      0.214062
# std            131.062003  ...      0.773007      0.721269      0.716264
# min           1622.564004  ...     -0.752068     -0.632821     -0.637660
# 25%           1800.035930  ...     -0.565767     -0.370874     -0.203954
# 50%           1866.671923  ...     -0.074624     -0.007782     -0.032591
# 75%           1944.053991  ...      0.766644      0.414613      0.512100
# max           2084.828317  ...      1.610606      1.759157      1.606404
#
#        mfcc_stat_89  mfcc_stat_90  mfcc_stat_91   P808_MOS     SIGMOS  \
# count     12.000000     12.000000     12.000000  12.000000  12.000000
# mean       0.194896      0.842238      0.161036   3.566431   3.379320
# std        0.551266      0.933084      0.581878   0.329182   0.118692
# min       -0.473619     -0.372096     -0.685689   3.119270   3.153388
# 25%       -0.299689      0.095977     -0.238152   3.370600   3.327689
# 50%        0.077009      0.752037      0.202361   3.528062   3.392454
# 75%        0.745877      1.301920      0.732268   3.700343   3.468482
# max        0.936560      2.650593      0.945537   4.323921   3.550609
#
#           BAKMOS     OVRMOS
# count  12.000000  12.000000
# mean    3.562575   2.893237
# std     0.335828   0.183000
# min     2.948222   2.670215
# 25%     3.392766   2.763333
# 50%     3.519188   2.849416
# 75%     3.738018   2.995812
# max     4.091464   3.199611
#
# [8 rows x 130 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,5))
sns.histplot(df['snr'], kde=True)
plt.title("Verteilung: SNR")
plt.show()

# %%
plt.figure(figsize=(12,10))
sns.heatmap(df.corr(), cmap='coolwarm', center=0)
plt.title("Korrelationsmatrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 plt.figure(figsize=(12,10))
# ----> 2 sns.heatmap(df.corr(), cmap='coolwarm', center=0)
#       3 plt.title("Korrelationsmatrix")
#       4 plt.show()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ma-env/lib/python3.9/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ma-env/lib/python3.9/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ma-env/lib/python3.9/site-packages/pandas/core/internals/managers.py:1694, in BlockManager.as_array(self, dtype, copy, na_value)
#    1692         arr.flags.writeable = False
#    1693 else:
# -> 1694     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1695     # The underlying data was copied within _interleave, so no need
#    1696     # to further copy if copy=True or setting na_value
#    1698 if na_value is lib.no_default:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/ma-env/lib/python3.9/site-packages/pandas/core/internals/managers.py:1753, in BlockManager._interleave(self, dtype, na_value)
#    1751     else:
#    1752         arr = blk.get_values(dtype)
# -> 1753     result[rl.indexer] = arr
#    1754     itemmask[rl.indexer] = 1
#    1756 if not itemmask.all():
#
# ValueError: could not convert string to float: 'common_voice_de_40390291.mp3'
