# %%
import pandas as pd

# %%
# Lade das reduzierte Feature-Set (nach PCA + VIF)
df = pd.read_csv("../results/subset_50h/features_pca_vif.csv")

# Optional: Zeige die ersten Zeilen
df.head()
# Out:
#         rms  log_energy  clipping_ratio  crest_factor        snr          f0  \
# 0  0.138755    7.460141        0.000044      7.206935  32.660785  100.887721
# 1  0.107539    7.020273        0.000052      9.298929  30.196857  135.333079
# 2  0.111006    7.192654        0.000065      9.008530  21.029661  182.299178
# 3  0.100967    7.010160        0.000101      9.904255  20.688646   96.783083
# 4  0.160976    7.385242        0.000209      6.212097  35.451932  102.276770
#
#    phoneme_entropy  rt60_reverberation  spectral_bandwidth  spectral_flatness  \
# 0         5.278837            4.124500         1566.968846           0.016414
# 1         5.394557            5.490875         1781.131421           0.037886
# 2         5.082705            6.386625         1835.400159           0.028636
# 3         5.229240            5.590375         1671.440418           0.044127
# 4         5.257475            2.706875         1423.227017           0.022996
#
# ...
